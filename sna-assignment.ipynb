# %%
! pip install networkx
! pip install plotly
! pip install colorlover
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (2.4)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx) (4.4.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (4.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly) (1.12.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly) (1.3.3)
# Requirement already satisfied: colorlover in /usr/local/lib/python3.6/dist-packages (0.3.0)

# %%
import networkx as nx
import pandas as pd

# %% [markdown]
# # Q1. Choose a hashtag

# %% [markdown]
#  #photography

# %%
df = pd.read_csv("tweets2009-06-0115.csv.zip", sep='\t', compression='zip')

# %%
print("Num of rows:", df.shape[0])
# Out:
# Num of rows: 3437690

# %%
df.head()
# Out:
#                   date        user          tweet
# 0  2009-06-01 21:43:59  burtonator  No Post Title
# 1  2009-06-01 21:47:23  burtonator  No Post Title
# 2  2009-06-02 01:15:44  burtonator  No Post Title
# 3  2009-06-02 05:17:52  burtonator  No Post Title
# 4  2009-06-02 23:58:25  burtonator  No Post Title

# %% [markdown]
# Find the most common hash tag

# %%
from collections import Counter

# %%
allTweets = df["tweet"].str.cat(sep=' ')
tweetWords = [word.strip(""" ,.:'\";""").lower() for word in allTweets.split()]
hashTags = [word for word in tweetWords if word.startswith("#")]
hashTagsCounter = Counter(hashTags)

# %%
hashTagsCounter.most_common(50)
# Out:
# [('#iranelection', 26853),
#  ('#followfriday', 16400),
#  ('#jobs', 13322),
#  ('#iremember', 11057),
#  ('#spymaster', 10587),
#  ('#ff', 10446),
#  ('#squarespace', 9198),
#  ('#tcot', 7691),
#  ('#fb', 6107),
#  ('#cnnfail', 4451),
#  ('#11thcommandment', 3429),
#  ('#jtv', 3317),
#  ('#140mafia', 3144),
#  ('#iran', 2935),
#  ('#', 2895),
#  ('#news', 2837),
#  ('#quote', 2750),
#  ('#vampirebite', 2634),
#  ('#1', 2587),
#  ('#bsb', 2433),
#  ('#tweetmyjobs', 2086),
#  ('#iphone', 1697),
#  ('#lastfm', 1599),
#  ('#mp2', 1589),
#  ('#niley', 1528),
#  ('#music', 1489),
#  ('#p2', 1439),
#  ('#follow', 1390),
#  ('#pawpawty', 1305),
#  ('#hhrs', 1256),
#  ('#fail', 1246),
#  ('#twitter', 1216),
#  ('#tlot', 1214),
#  ('#facebook', 1177),
#  ('#sgp', 1151),
#  ('#mashchat', 1143),
#  ('#tinychat', 1111),
#  ('#2', 1107),
#  ('#digg', 1102),
#  ('#gop', 1009),
#  ('#phish', 1001),
#  ('#mlb', 962),
#  ('#travel', 932),
#  ('#bonnaroo', 887),
#  ('#twitpocalypse', 879),
#  ('#iranelections', 857),
#  ('#rt', 856),
#  ('#zensursula', 811),
#  ('#jamlegend', 790),
#  ('#quotes', 756)]

# %%
pgTag = df[df["tweet"].str.lower().str.contains("#photography", na=False)].copy()

# %%
def addMentionedColumn(df):
    
    def mentionsList(txt):
        allWords = [word.strip(""" ,.:'\";""").lower() for word in txt.split()]
        allNames = [word.strip("@") for word in allWords if word.startswith("@")]
        uniqueNames = list(set(allNames))
        return allNames
    
    df["mentioned"] = df["tweet"].apply(mentionsList)

# %%
addMentionedColumn(pgTag)

# %%
pgTag.head(50)
# Out:
#                        date  ...                                          mentioned
# 1147    2009-06-11 16:58:53  ...                                                 []
# 12882   2009-06-11 17:15:44  ...                                                 []
# 14482   2009-06-11 17:17:56  ...                                                 []
# 15171   2009-06-11 17:18:34  ...                                                 []
# 23958   2009-06-11 17:32:48  ...                                                 []
# 31519   2009-06-11 17:46:37  ...                                         [murrayed]
# 34693   2009-06-11 17:51:09  ...                                                 []
# 40725   2009-06-11 17:59:57  ...                                                 []
# 41012   2009-06-11 18:00:18  ...                                                 []
# 44876   2009-06-11 18:05:45  ...                                                 []
# 46686   2009-06-11 18:07:26  ...                                                 []
# 55667   2009-06-11 18:20:38  ...                                     [quiteuseful)]
# 55972   2009-06-11 18:21:00  ...                                                 []
# 57992   2009-06-11 18:23:54  ...                                                 []
# 62571   2009-06-11 18:31:46  ...                                                 []
# 67808   2009-06-11 18:43:39  ...                                         [popphoto]
# 72726   2009-06-11 18:50:22  ...                                                 []
# 80727   2009-06-11 19:04:50  ...                                                 []
# 90271   2009-06-11 19:19:48  ...                                                 []
# 92619   2009-06-11 19:22:52  ...                                         [havepack]
# 99511   2009-06-11 19:35:37  ...                                                 []
# 110247  2009-06-11 19:50:00  ...                                        [geofollow]
# 116366  2009-06-11 19:58:42  ...                                      [photoframd)]
# 116673  2009-06-11 19:58:58  ...                                                 []
# 117414  2009-06-11 19:59:41  ...                              [gregkb, andrewhyde)]
# 118496  2009-06-11 20:00:48  ...                                        [havepack)]
# 119944  2009-06-11 20:06:18  ...  [fantasyparade, mojolabs, hypem, housymphony, ...
# 121075  2009-06-11 20:10:04  ...                                                 []
# 122186  2009-06-11 20:12:18  ...                                      [photoframd)]
# 124202  2009-06-11 20:16:45  ...                                                 []
# 124929  2009-06-11 20:17:52  ...                                    [hammer_museum]
# 129428  2009-06-11 20:26:11  ...                                                 []
# 134487  2009-06-11 20:36:22  ...                                         [jasondpg]
# 153197  2009-06-11 21:04:56  ...                                                 []
# 154116  2009-06-11 21:07:55  ...                                                 []
# 172617  2009-06-11 21:42:53  ...                                                 []
# 180823  2009-06-11 21:53:31  ...                                                 []
# 190897  2009-06-11 22:03:27  ...                                     [wearephotogs]
# 190898  2009-06-11 22:03:27  ...                                     [wearephotogs]
# 197138  2009-06-11 22:10:12  ...                                                 []
# 205392  2009-06-11 22:22:01  ...                                      [jeanevogel}]
# 205991  2009-06-11 22:23:58  ...                                                 []
# 218338  2009-06-11 22:47:05  ...                                                 []
# 223464  2009-06-11 22:54:08  ...                                                 []
# 225362  2009-06-11 22:57:10  ...                                                 []
# 230871  2009-06-11 23:05:49  ...                                                 []
# 237099  2009-06-11 23:14:35  ...                                                 []
# 237607  2009-06-11 23:15:13  ...                                                 []
# 240177  2009-06-11 23:18:21  ...                                                 []
# 251122  2009-06-11 23:36:25  ...                                  [redraincreative]
#
# [50 rows x 4 columns]

# %%
pgTag.shape
# Out:
# (658, 4)

# %% [markdown]
# # Q2. Build a Mention Graph

# %%
def mentionGraph(df):
    g = nx.Graph()
    
    for (index, date, user, tweet, mentionedUsers) in df.itertuples():
        for mentionedUser in mentionedUsers:
            if (user in g) and (mentionedUser in g[user]):
                g[user][mentionedUser]["numberMentions"] += 1
            else:
                g.add_edge(user, mentionedUser, numberMentions=1)
    
    return g

# %%
pgGraph = mentionGraph(pgTag)

# %%
# use nx.info to show the nodes and edges, also average degree
print(nx.info(pgGraph))
# Out:
# Name:
# Type: Graph
# Number of nodes: 352
# Number of edges: 304
# Average degree:   1.7273

# %%
print("# nodes:", len(pgGraph.nodes()))
print("# edges:", len(pgGraph.edges()))
# Out:
# # nodes: 352
# # edges: 304

# %%
degree_ls = [val for (node, val) in pgGraph.degree()]

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = degree_ls
plt.hist(x, bins = 70)
plt.xlabel('degree level')
plt.ylabel('degree freq');

# %% [markdown]
# top 5 edges with highest weights

# %%
def weight_dict(G):
    weight_dict = {}
    for (u,v) in G.edges():
        edgeWidth = G[u][v]['numberMentions']
        weight_dict[(u,v)] = edgeWidth
    return weight_dict

fb_edge_dict = weight_dict(pgGraph)

# %%
top_5_edge = sorted(fb_edge_dict.items(), key=lambda x: -x[1])[:5]

# %%
top_5_edge
# Out:
# [(('photocentrum', 'fpresources'), 11),
#  (('', 'fpresources'), 4),
#  (('polaroidteam', 'polaroidgirl'), 4),
#  (('catherinegrison', 'hopfoot'), 4),
#  (('catherinegrison', 'fpresources'), 4)]

# %%
pgGraph['photocentrum']
# Out:
# AtlasView({'': {'numberMentions': 3}, 'fpresources': {'numberMentions': 11}, 'andrewbuxton': {'numberMentions': 1}})

# %% [markdown]
# # Visualize Mention Graph

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.graph_objs import *
import plotly.graph_objects as go
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %%
import random
def addRandomPositions(graph):
    posDict = dict((node,(random.gauss(0,10),random.gauss(0,10))) for node in graph.nodes())
    nx.set_node_attributes(graph, name="pos", values=posDict)

# %%
addRandomPositions(pgGraph)

# %%
nx.get_node_attributes(pgGraph, 'pos')['pwcarey']
# Out:
# (-9.98258135813841, -28.409247751793888)

# %% [markdown]
# ### Visualize using Plot.ly scatter plots

# %%
def plotNetwork(graph):
    scatters=[]

    for (node1, node2) in graph.edges():
        x0, y0 = graph.nodes[node1]['pos']
        x1, y1 = graph.nodes[node2]['pos']
        edgeWidth = graph[node1][node2]['numberMentions']
        s = Scatter(
                x=[x0, x1],
                y=[y0, y1],
                hoverinfo='none',
                mode='lines', 
                line=scatter.Line(width=1 ,color='#888'))
        scatters.append(s)



    for node in graph.nodes():
        xPos, yPos = graph.nodes[node]['pos']
        s = Scatter(
                x=[xPos], 
                y=[yPos], 
                hoverinfo='none',
                mode='markers', 
                marker=dict(
                    color="#888", 
                    size=10,         
                    line=dict(width=1.5)))
        scatters.append(s)
    
    layout = Layout(showlegend=False)
    fig = Figure(data=scatters, layout=layout)
    iplot(fig, show_link=False)

# %%
pgGraph.nodes['pwcarey']['pos']
# Out:
# (-9.98258135813841, -28.409247751793888)

# %%
configure_plotly_browser_state()
plotNetwork(pgGraph)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="0c1c23ea-5ace-41f2-a246-75b9ea6f0956" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c1c23ea-5ace-41f2-a246-75b9ea6f0956")) {
#                     Plotly.newPlot(
#                         '0c1c23ea-5ace-41f2-a246-75b9ea6f0956',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-9.98258135813841, 2.7040528268426884], "y": [-28.409247751793888, 7.007433004180501]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [2.7040528268426884, -3.97266398423462], "y": [7.007433004180501, 17.352872766656734]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 17.818315013968768], "y": [6.990038856265109, 5.166281061874755]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.562234561109435], "y": [6.990038856265109, 2.4822684103250063]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.259544781075992], "y": [6.990038856265109, 5.876867125104638]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 11.829423528029459], "y": [5.166281061874755, -11.459771165485982]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 5.596741787037005], "y": [5.166281061874755, -2.891802201518602]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -10.59504194952697], "y": [5.166281061874755, 6.0460247701439505]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 8.375202999727753], "y": [5.166281061874755, -9.732934522013784]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -27.966801015049455], "y": [5.166281061874755, 0.5208824809493185]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -2.1589555906822553], "y": [5.166281061874755, -0.30648583201863194]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 4.562234561109435], "y": [5.166281061874755, 2.4822684103250063]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-1.115467588994997, 6.991239249393764], "y": [1.2950212978373599, 18.44669895390712]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [14.426346309164513, -8.100421678143702], "y": [-11.211038548138031, -1.0884166964510498]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [7.4044469149634295, 15.149872731398053], "y": [-12.300512269707927, -16.74411046279273]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 15.149872731398053], "y": [-16.74411046279273, -16.74411046279273]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 13.773235440253638], "y": [-16.74411046279273, -10.822465053907118]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -4.8123751782888515], "y": [-16.74411046279273, -5.721441483185739]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -7.827289470571387], "y": [-16.74411046279273, -3.894911122211393]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 8.302360180930721], "y": [-16.74411046279273, 14.905127783789748]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.702477071220065, 10.693587585515498], "y": ...

# %%
def plotNetworkSize(graph):
    scatters=[]

    for (node1, node2) in graph.edges():
        x0, y0 = graph.nodes[node1]['pos']
        x1, y1 = graph.nodes[node2]['pos']
        edgeWidth = graph[node1][node2]['numberMentions']
        s = Scatter(
                x=[x0, x1],
                y=[y0, y1],
                hoverinfo='text',
                mode='lines', 
                line=scatter.Line(width=edgeWidth ,color='#777'))
        scatters.append(s)



    for node in graph.nodes():
        xPos, yPos = graph.nodes[node]['pos']
        s = Scatter(
                x=[xPos], 
                y=[yPos], 
                hoverinfo='none',
                mode='markers', 
                marker=dict(
                    color="#888", 
                    size=nx.degree(graph,node)*2,         
                    line=dict(width=2)))
        scatters.append(s)
    
    layout = Layout(showlegend=False)
    fig = Figure(data=scatters, layout=layout)
    iplot(fig, show_link=False)

# %%
configure_plotly_browser_state()
plotNetworkSize(pgGraph)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="a7a4687e-214a-472a-a631-3ba18ddcb106" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a7a4687e-214a-472a-a631-3ba18ddcb106")) {
#                     Plotly.newPlot(
#                         'a7a4687e-214a-472a-a631-3ba18ddcb106',
#                         [{"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [-9.98258135813841, 2.7040528268426884], "y": [-28.409247751793888, 7.007433004180501]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [2.7040528268426884, -3.97266398423462], "y": [7.007433004180501, 17.352872766656734]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 3}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 17.818315013968768], "y": [6.990038856265109, 5.166281061874755]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 11}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.562234561109435], "y": [6.990038856265109, 2.4822684103250063]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.259544781075992], "y": [6.990038856265109, 5.876867125104638]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 11.829423528029459], "y": [5.166281061874755, -11.459771165485982]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 5.596741787037005], "y": [5.166281061874755, -2.891802201518602]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -10.59504194952697], "y": [5.166281061874755, 6.0460247701439505]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 8.375202999727753], "y": [5.166281061874755, -9.732934522013784]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -27.966801015049455], "y": [5.166281061874755, 0.5208824809493185]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -2.1589555906822553], "y": [5.166281061874755, -0.30648583201863194]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 4}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 4.562234561109435], "y": [5.166281061874755, 2.4822684103250063]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [-1.115467588994997, 6.991239249393764], "y": [1.2950212978373599, 18.44669895390712]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [14.426346309164513, -8.100421678143702], "y": [-11.211038548138031, -1.0884166964510498]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [7.4044469149634295, 15.149872731398053], "y": [-12.300512269707927, -16.74411046279273]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 15.149872731398053], "y": [-16.74411046279273, -16.74411046279273]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 13.773235440253638], "y": [-16.74411046279273, -10.822465053907118]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -4.8123751782888515], "y": [-16.74411046279273, -5.721441483185739]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -7.827289470571387], "y": [-16.74411046279273, -3.894911122211393]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 8.302360180930721], "y": [-16.74411046279273, 14.905127783789748]}, {"hoverinfo": "text", "line": {"color": "#777", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.702477071220065, 10.693587585515498], "y" ...

# %%
import colorlover as cl
from IPython.display import HTML

# %%
# map purd color scale to 300 cells
purd = cl.scales['9']['seq']['YlOrRd']
purd300 = cl.interp(purd, 300)
HTML(cl.to_html(purd300))
# Out:
# <div style="background-color:hsl(60.0, 100.0%, 90.0%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(59.67892976588629, 100.0%, 89.75919732441471%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(59.357859531772576, 100.0%, 89.51839464882943%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(59.03678929765886, 100.0%, 89.27759197324414%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(58.71571906354515, 100.0%, 89.03678929765886%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(58.39464882943144, 100.0%, 88.79598662207358%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(58.07357859531773, 100.0%, 88.5551839464883%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(57.752508361204015, 100.0%, 88.31438127090301%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(57.4314381270903, 100.0%, 88.07357859531773%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(57.11036789297659, 100.0%, 87.83277591973244%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(56.78929765886288, 100.0%, 87.59197324414716%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(56.468227424749166, 100.0%, 87.35117056856187%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(56.147157190635454, 100.0%, 87.11036789297658%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(55.82608695652174, 100.0%, 86.86956521739131%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(55.50501672240803, 100.0%, 86.62876254180603%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(55.18394648829431, 100.0%, 86.38795986622074%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(54.862876254180605, 100.0%, 86.14715719063545%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(54.541806020066886, 100.0%, 85.90635451505017%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(54.22073578595318, 100.0%, 85.66555183946488%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(53.89966555183946, 100.0%, 85.4247491638796%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(53.57859531772576, 100.0%, 85.18394648829431%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(53.25752508361204, 100.0%, 84.94314381270902%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(52.936454849498325, 100.0%, 84.70234113712374%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(52.61538461538461, 100.0%, 84.46153846153847%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(52.2943143812709, 100.0%, 84.22073578595318%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(51.97324414715719, 100.0%, 83.9799331103679%);height:20px;width:20px;margin-bottom:0px;display:inline-block;"></div><div style="background-color:hsl(51.65217391304348, 100.0%, 83.73913043478261%);height:20px;width:20px;margin-bottom:0px;dis ...

# %%
def plotNetworkSizeColor(graph):
    closenessCentr = nx.closeness_centrality(pgGraph)
    maxCentr = max(closenessCentr.values())
    minCentr = min(closenessCentr.values())
    
    scatters=[]

    for (node1, node2) in graph.edges():
        x0, y0 = graph.nodes[node1]['pos']
        x1, y1 = graph.nodes[node2]['pos']
        edgeWidth = graph[node1][node2]['numberMentions']
        s = Scatter(
                x=[x0, x1],
                y=[y0, y1],
                hoverinfo='none',
                mode='lines', 
                line=scatter.Line(width=edgeWidth ,color='#888'))
        scatters.append(s)



    for node in graph.nodes():
        nodeCentr = closenessCentr[node]
        nodeColor = int(299*(nodeCentr-minCentr)/(maxCentr-minCentr))
        xPos, yPos = graph.nodes[node]['pos']
        s = Scatter(
                x=[xPos], 
                y=[yPos], 
                text="User: %s\nCloseness: %.3f" % (node, nodeCentr),
                hoverinfo='text',
                mode='markers', 
                marker=dict(
                    color=purd300[nodeColor], 
                    size=nx.degree(graph,node)*2,         
                    line=dict(width=2)))
        scatters.append(s)
    
    layout = Layout(showlegend=False)
    fig = Figure(data=scatters, layout=layout)
    iplot(fig, show_link=False)

# %%
configure_plotly_browser_state()
plotNetworkSizeColor(pgGraph)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="5fab85f0-c27c-47ac-80c2-d740f8c90bf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5fab85f0-c27c-47ac-80c2-d740f8c90bf8")) {
#                     Plotly.newPlot(
#                         '5fab85f0-c27c-47ac-80c2-d740f8c90bf8',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-9.98258135813841, 2.7040528268426884], "y": [-28.409247751793888, 7.007433004180501]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [2.7040528268426884, -3.97266398423462], "y": [7.007433004180501, 17.352872766656734]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 3}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 17.818315013968768], "y": [6.990038856265109, 5.166281061874755]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 11}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.562234561109435], "y": [6.990038856265109, 2.4822684103250063]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-3.180945593669397, 4.259544781075992], "y": [6.990038856265109, 5.876867125104638]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 11.829423528029459], "y": [5.166281061874755, -11.459771165485982]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 5.596741787037005], "y": [5.166281061874755, -2.891802201518602]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -10.59504194952697], "y": [5.166281061874755, 6.0460247701439505]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 8.375202999727753], "y": [5.166281061874755, -9.732934522013784]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -27.966801015049455], "y": [5.166281061874755, 0.5208824809493185]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, -2.1589555906822553], "y": [5.166281061874755, -0.30648583201863194]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4}, "mode": "lines", "type": "scatter", "x": [17.818315013968768, 4.562234561109435], "y": [5.166281061874755, 2.4822684103250063]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-1.115467588994997, 6.991239249393764], "y": [1.2950212978373599, 18.44669895390712]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [14.426346309164513, -8.100421678143702], "y": [-11.211038548138031, -1.0884166964510498]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [7.4044469149634295, 15.149872731398053], "y": [-12.300512269707927, -16.74411046279273]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 15.149872731398053], "y": [-16.74411046279273, -16.74411046279273]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 13.773235440253638], "y": [-16.74411046279273, -10.822465053907118]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -4.8123751782888515], "y": [-16.74411046279273, -5.721441483185739]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, -7.827289470571387], "y": [-16.74411046279273, -3.894911122211393]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.149872731398053, 8.302360180930721], "y": [-16.74411046279273, 14.905127783789748]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [15.702477071220065, 10.693587585515498], "y" ...

# %% [markdown]
# #Q3. Content Analysis

# %% [markdown]
# a) the most common words in tweets

# %%
pgTag[['tweet']].head()
# Out:
#                                                    tweet
# 1147   Took a walk at lunch. My lunch-time architectu...
# 12882  Just added myself to the http://wefollow.com t...
# 14482  Just added myself to the http://wefollow.com t...
# 15171  All I can find at the moment about the Noche d...
# 23958  Finally got around to setting up my #photograp...

# %%
twts = pgTag['tweet']

# %%
! pip install tweet-preprocessor
import preprocessor as p
# this is the package that helps you clean tweets text
# Out:
# Collecting tweet-preprocessor
#   Downloading https://files.pythonhosted.org/packages/2a/f8/810ec35c31cca89bc4f1a02c14b042b9ec6c19dd21f7ef1876874ef069a6/tweet-preprocessor-0.5.0.tar.gz
# Building wheels for collected packages: tweet-preprocessor
#   Building wheel for tweet-preprocessor (setup.py) ... done
#   Created wheel for tweet-preprocessor: filename=tweet_preprocessor-0.5.0-cp36-none-any.whl size=7947 sha256=e26163af19434b64e333ac03b2631a3954c92fa2bae4b9901531780657e5a98d
#   Stored in directory: /root/.cache/pip/wheels/1b/27/cc/49938e98a2470802ebdefae9d2b3f524768e970c1ebbe2dc4a
# Successfully built tweet-preprocessor
# Installing collected packages: tweet-preprocessor
# Successfully installed tweet-preprocessor-0.5.0

# %%
clean_tweets = twts.apply(lambda x: p.clean(x))

# %%
pgTag['clean_tweets'] = clean_tweets

# %%
pgTag.head()
# Out:
#                       date  ...                                       clean_tweets
# 1147   2009-06-11 16:58:53  ...  Took a walk at lunch. My lunch-time architectu...
# 12882  2009-06-11 17:15:44  ...  Just added myself to the twitter directory under:
# 14482  2009-06-11 17:17:56  ...  Just added myself to the twitter directory under:
# 15171  2009-06-11 17:18:34  ...  All I can find at the moment about the Noche d...
# 23958  2009-06-11 17:32:48  ...  Finally got around to setting up my studio! Ju...
#
# [5 rows x 5 columns]

# %%
# clean txt and tokenize
# reference https://towardsdatascience.com/detecting-bad-customer-reviews-with-nlp-d8b36134dc7e
#! pip install nltk
#nltk.download("stopwords")
import re
import nltk
import string
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    # remove stop words
    stop_words = set(stopwords.words('english')) 
    text = [x for x in text if x not in stop_words]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# applying function and clean data
pgTag['clean_tweets'] = pgTag['clean_tweets'].apply(lambda x: clean_text(x))

# %%
pgTag.head(10)
# Out:
#                       date  ...                                       clean_tweets
# 1147   2009-06-11 16:58:53  ...  take walk lunch lunch-time architectural photo...
# 12882  2009-06-11 17:15:44  ...                              add twitter directory
# 14482  2009-06-11 17:17:56  ...                              add twitter directory
# 15171  2009-06-11 17:18:34  ...                    find moment noche de fotografia
# 23958  2009-06-11 17:32:48  ...  finally get around set studio basic camera lig...
# 31519  2009-06-11 17:46:37  ...  thanks book recommend use form today wedding c...
# 34693  2009-06-11 17:51:09  ...     official new writeup lexjet focus photographer
# 40725  2009-06-11 17:59:57  ...  kata's pr bag grab gear go reporter anyone els...
# 41012  2009-06-11 18:00:18  ...  casio exilim last update review sample photo s...
# 44876  2009-06-11 18:05:45  ...                     sad apple tree blossoming plea
#
# [10 rows x 5 columns]

# %%
import collections
itemAnalysisDf = pgTag[['clean_tweets']]
def getTopK(df, k, value_column='clean_tweets'):
    stop = stopwords.words('english')
    #Add possible Stop Words for Hotel Reviews
    stop.append('twitter')

    counter = Counter()
    for review in df[value_column]:
            counter.update([word.lower() 
                            for word 
                            in re.findall(r'\w+', review) 
                            if word.lower() not in stop and len(word) > 2])
    topk = counter.most_common(k)
    return topk

# %%
topk = getTopK(df=itemAnalysisDf, k=50)

# %%
topk
# Out:
# [('photo', 107),
#  ('add', 80),
#  ('directory', 74),
#  ('photography', 68),
#  ('day', 51),
#  ('via', 47),
#  ('shot', 41),
#  ('new', 41),
#  ('review', 33),
#  ('blog', 32),
#  ('digital', 30),
#  ('get', 29),
#  ('great', 28),
#  ('check', 26),
#  ('canon', 25),
#  ('post', 24),
#  ('image', 22),
#  ('nice', 20),
#  ('camera', 19),
#  ('photographer', 19),
#  ('world', 19),
#  ('today', 18),
#  ('powershot', 18),
#  ('flickr', 18),
#  ('like', 17),
#  ('take', 16),
#  ('use', 16),
#  ('update', 16),
#  ('free', 16),
#  ('look', 15),
#  ('beautiful', 15),
#  ('nature', 15),
#  ('set', 14),
#  ('pic', 14),
#  ('exceptional', 14),
#  ('love', 13),
#  ('photograph', 13),
#  ('see', 13),
#  ('tip', 13),
#  ('job', 12),
#  ('essay', 12),
#  ('high', 12),
#  ('shoot', 12),
#  ('light', 11),
#  ('man', 11),
#  ('wonder', 11),
#  ('last', 10),
#  ('know', 10),
#  ('video', 10),
#  ('speed', 10)]

# %% [markdown]
# we can clearly see that the most common words are really close to photo and behavior related to taking photos

# %% [markdown]
# c) add hover info to show more details
#
# most common words for each user

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
tk = pgTag[['user', 'clean_tweets']]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
tk['tk_words'] = tk['clean_tweets'].apply(word_tokenize)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
tk = tk[['user', 'tk_words']]
tk.head()
# Out:
#                user                                           tk_words
# 1147         base10  [take, walk, lunch, lunch-time, architectural,...
# 12882  replayphotos                          [add, twitter, directory]
# 14482      cottontw                          [add, twitter, directory]
# 15171       gospain              [find, moment, noche, de, fotografia]
# 23958         hiway  [finally, get, around, set, studio, basic, cam...

# %%
tk['tk_words'].apply(lambda x: [k for k, v in Counter(x).most_common(3)])
# Out:
# 1147             [take, walk, lunch]
# 12882      [add, twitter, directory]
# 14482      [add, twitter, directory]
# 15171          [find, moment, noche]
# 23958         [finally, get, around]
#                      ...
# 3416456      [useful, action, photo]
# 3418053    [bruce, percy, portfolio]
# 3431662         [awesome, set, long]
# 3431663         [awesome, set, long]
# 3435787     [gate, interest, series]
# Name: tk_words, Length: 658, dtype: object

# %%
tk_new = tk.groupby(by = tk['user'])['tk_words'].apply(list).reset_index(name = 'common_words')

# %%
tk_new.head()
# Out:
#               user                                       common_words
# 0         02138now   [[fresh, love, farmer, market, harvard, square]]
# 1             0lli           [[portrait, landscape, dolce, pic, tip]]
# 2  1001noisycamera  [[add, blog, twitter, directory], [congrats, r...
# 3              1kc  [[canon, powershot, review, via], [photo, tip,...
# 4        2live4him                                    [[free, brush]]

# %%
import itertools
def merge(text):      
    merged = list(itertools.chain.from_iterable(text))
    return merged
tk_new['common_words'] = tk_new['common_words'].apply(merge)

# %%
tk_new.head()
# Out:
#               user                                       common_words
# 0         02138now     [fresh, love, farmer, market, harvard, square]
# 1             0lli             [portrait, landscape, dolce, pic, tip]
# 2  1001noisycamera  [add, blog, twitter, directory, congrats, rt, ...
# 3              1kc  [canon, powershot, review, via, photo, tip, we...
# 4        2live4him                                      [free, brush]

# %%
tk_new['top3_words'] = tk_new['common_words'].apply(lambda x: [k for k, v in Counter(x).most_common(3)])
tk_new.head()
# Out:
#               user  ...                    top3_words
# 0         02138now  ...         [fresh, love, farmer]
# 1             0lli  ...  [portrait, landscape, dolce]
# 2  1001noisycamera  ...            [pool, rt, flickr]
# 3              1kc  ...       [via, canon, powershot]
# 4        2live4him  ...                 [free, brush]
#
# [5 rows x 3 columns]

# %%
#tk_new['user'][2]
tk_new.set_index('user', inplace=True)

# %%
tk_new.head()
# Out:
#                                                       common_words                    top3_words
# user
# 02138now            [fresh, love, farmer, market, harvard, square]         [fresh, love, farmer]
# 0lli                        [portrait, landscape, dolce, pic, tip]  [portrait, landscape, dolce]
# 1001noisycamera  [add, blog, twitter, directory, congrats, rt, ...            [pool, rt, flickr]
# 1kc              [canon, powershot, review, via, photo, tip, we...       [via, canon, powershot]
# 2live4him                                            [free, brush]                 [free, brush]

# %%
def plotNetworkWidthColor_Top3(graph):
    closenessCentr = nx.closeness_centrality(pgGraph)
    maxCentr = max(closenessCentr.values())
    minCentr = min(closenessCentr.values())
    
    scatters=[]

    for (node1, node2) in graph.edges():
        x0, y0 = graph.nodes[node1]['pos']
        x1, y1 = graph.nodes[node2]['pos']
        edgeWidth = graph[node1][node2]['numberMentions']
        s = Scatter(
                x=[x0, x1],
                y=[y0, y1],
                hoverinfo='none',
                mode='lines', 
                line=scatter.Line(width=edgeWidth ,color='#888'))
        scatters.append(s)



    for node in graph.nodes():
        nodeCentr = closenessCentr[node]
        top3 = getTopK(df=itemAnalysisDf, k=3)
        nodeColor = int(299*(nodeCentr-minCentr)/(maxCentr-minCentr))
        xPos, yPos = graph.nodes[node]['pos']
        for index, row in tk_new.iterrows():
            if node == index:
                s = Scatter(
                        x=[xPos], 
                        y=[yPos], 
                        #text="User: %s\nCloseness: %.3f" % (node, nodeCentr),
                        hoverinfo='text',
                        text = 'Node: %s,Top words: %s' % (node, tk_new.loc[index]['top3_words']),
                        mode='markers', 
                        marker=dict(
                            color=purd300[nodeColor], 
                            size=nx.degree(graph,node)*2,         
                            line=dict(width=2)))
                scatters.append(s)
    
    layout = Layout(showlegend=False)
    fig = Figure(data=scatters, layout=layout)
    iplot(fig, show_link=False)

# %%
def applyLayout(graph, layoutFunc):
    posDict = layoutFunc(graph) 
    nx.set_node_attributes(graph, name="pos", values=posDict)

# %%
pgGraph_top3 = pgGraph.copy()
applyLayout(pgGraph_top3, nx.spring_layout)
configure_plotly_browser_state()
plotNetworkWidthColor_Top3(pgGraph_top3)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="4a00814c-f276-43c0-aac0-e24c7d7a7f02" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4a00814c-f276-43c0-aac0-e24c7d7a7f02")) {
#                     Plotly.newPlot(
#                         '4a00814c-f276-43c0-aac0-e24c7d7a7f02',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.7479424798149836, 0.720789334161648], "y": [0.49603676321230367, 0.4828800763324115]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.720789334161648, 0.6868796259783967], "y": [0.4828800763324115, 0.4654797630622542]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 3}, "mode": "lines", "type": "scatter", "x": [-0.08611407451941351, -0.0839371105470324], "y": [0.12850735573988564, 0.15926862827398564]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 11}, "mode": "lines", "type": "scatter", "x": [-0.08611407451941351, -0.0650330825835583], "y": [0.12850735573988564, 0.07537939960365507]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.08611407451941351, -0.11321414034158463], "y": [0.12850735573988564, 0.15692859388418298]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.06427825410638911], "y": [0.15926862827398564, 0.12155935455198826]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.08644379764300296], "y": [0.15926862827398564, 0.20819494431983468]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.10786053537815402], "y": [0.15926862827398564, 0.20406381051774833]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.11641628538723287], "y": [0.15926862827398564, 0.18960421262865113]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.0938838667084639], "y": [0.15926862827398564, 0.19619189919610325]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.06116566592802912], "y": [0.15926862827398564, 0.19191445023721332]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4}, "mode": "lines", "type": "scatter", "x": [-0.0839371105470324, -0.0650330825835583], "y": [0.15926862827398564, 0.07537939960365507]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.594158526779709, -0.5689323141661781], "y": [0.62600306814121, 0.5983073046742066]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.46468475897697226, -0.47465191524984734], "y": [0.6837831510727114, 0.6693696048961391]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.49247405852993636, -0.4573561209199578], "y": [-0.5815177295110606, -0.5666393274249701]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.4573561209199578, -0.4573561209199578], "y": [-0.5666393274249701, -0.5666393274249701]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.4573561209199578, -0.4583825885699946], "y": [-0.5666393274249701, -0.5905778797927939]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.4573561209199578, -0.4377941923983283], "y": [-0.5666393274249701, -0.5879895876325701]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.4573561209199578, -0.47498687358250935], "y": [-0.5666393274249701, -0.5891397459256433]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [-0.4573561209199578, -0.4504967971565862], "y": [-0.5666393274249701, -0.5413396475533443]}, {"hoverinfo": "none", "line": {"color": "#888", "width":  ...

# %% [markdown]
# # Q4. Centrality Analysis

# %% [markdown]
# a) choose two centrality measures

# %%
degree_centr = nx.degree_centrality(pgGraph)

# %%
page_centr = nx.pagerank(pgGraph)

# %% [markdown]
# b) visualization

# %%
def plotNetworkWidthColor_Top3(graph, centrality):
    
    closenessCentr = nx.closeness_centrality(pgGraph)
    maxCentr = max(centrality.values())
    minCentr = min(centrality.values())
    
    scatters=[]

    for (node1, node2) in graph.edges():
        x0, y0 = graph.nodes[node1]['pos']
        x1, y1 = graph.nodes[node2]['pos']
        edgeWidth = graph[node1][node2]['numberMentions']
        s = Scatter(
                x=[x0, x1],
                y=[y0, y1],
                hoverinfo='none',
                mode='lines', 
                line=scatter.Line(width=edgeWidth ,color='#888'))
        scatters.append(s)



    for node in graph.nodes():
        nodeCentr = centrality[node]
        top3 = getTopK(df=itemAnalysisDf, k=3)
        nodeColor = int(299*(nodeCentr-minCentr)/(maxCentr-minCentr))
        xPos, yPos = graph.nodes[node]['pos']
        for index, row in tk_new.iterrows():
            if node == index:
                s = Scatter(
                        x=[xPos], 
                        y=[yPos], 
                        #text="User: %s\nCloseness: %.3f" % (node, nodeCentr),
                        hoverinfo='text',
                        text = 'Node: %s,Top words: %s, Centr: %s' % (node, tk_new.loc[index]['top3_words'], nodeCentr),
                        mode='markers', 
                        marker=dict(
                            color=purd300[nodeColor], 
                            size=nx.degree(graph,node)*2,         
                            line=dict(width=2)))
                scatters.append(s)
    
    layout = Layout(showlegend=False)
    fig = Figure(data=scatters, layout=layout)
    iplot(fig, show_link=False)

# %%
pgGraph_top3 = pgGraph.copy()
applyLayout(pgGraph_top3, nx.random_layout)
configure_plotly_browser_state()
plotNetworkWidthColor_Top3(pgGraph_top3, degree_centr)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="a99ecc6d-d9cb-4c1f-a194-71599b780ab5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a99ecc6d-d9cb-4c1f-a194-71599b780ab5")) {
#                     Plotly.newPlot(
#                         'a99ecc6d-d9cb-4c1f-a194-71599b780ab5',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9307298064231873, 0.47863906621932983], "y": [0.9894284009933472, 0.7103925943374634]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.47863906621932983, 0.7627045512199402], "y": [0.7103925943374634, 0.02695596031844616]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 3}, "mode": "lines", "type": "scatter", "x": [0.5858820676803589, 0.7188206911087036], "y": [0.04345696046948433, 0.01855531893670559]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 11}, "mode": "lines", "type": "scatter", "x": [0.5858820676803589, 0.056371890008449554], "y": [0.04345696046948433, 0.6126037240028381]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5858820676803589, 0.4089779555797577], "y": [0.04345696046948433, 0.8159471750259399]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.07257193326950073], "y": [0.01855531893670559, 0.15989039838314056]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.9569171071052551], "y": [0.01855531893670559, 0.1691361516714096]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.3248584270477295], "y": [0.01855531893670559, 0.8213682174682617]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.7362887263298035], "y": [0.01855531893670559, 0.048637256026268005]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.5916523337364197], "y": [0.01855531893670559, 0.9896463751792908]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.7542703151702881], "y": [0.01855531893670559, 0.6919968724250793]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4}, "mode": "lines", "type": "scatter", "x": [0.7188206911087036, 0.056371890008449554], "y": [0.01855531893670559, 0.6126037240028381]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.021446725353598595, 0.7446397542953491], "y": [0.2990281581878662, 0.7176042795181274]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5249337553977966, 0.4512258470058441], "y": [0.2172209769487381, 0.785180389881134]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9678110480308533, 0.5582515597343445], "y": [0.3787192702293396, 0.7298938632011414]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5582515597343445, 0.5582515597343445], "y": [0.7298938632011414, 0.7298938632011414]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5582515597343445, 0.7723778486251831], "y": [0.7298938632011414, 0.9192770719528198]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5582515597343445, 0.49709996581077576], "y": [0.7298938632011414, 0.34988075494766235]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5582515597343445, 0.8330867290496826], "y": [0.7298938632011414, 0.01978951133787632]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.5582515597343445, 0.8145384788513184], "y": [0.7298938632011414, 0.09231729060411453]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.62 ...

# %%
pgGraph_top3 = pgGraph.copy()
applyLayout(pgGraph_top3, nx.circular_layout)
configure_plotly_browser_state()
plotNetworkWidthColor_Top3(pgGraph_top3, page_centr)
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="bd72fbb3-d10c-4033-bc44-45e80c5db10c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bd72fbb3-d10c-4033-bc44-45e80c5db10c")) {
#                     Plotly.newPlot(
#                         'bd72fbb3-d10c-4033-bc44-45e80c5db10c',
#                         [{"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9999999999742326, 0.9998406767588929], "y": [9.098108520908394e-10, 0.017849010377624284]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9998406767588929, -0.7318944915530984], "y": [0.017849010377624284, -0.6814179405173468]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 3}, "mode": "lines", "type": "scatter", "x": [0.9993628263221633, 0.9985665678733333], "y": [0.03569233505244744, 0.05352428641599974]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 11}, "mode": "lines", "type": "scatter", "x": [0.9993628263221633, 0.3494641190467795], "y": [0.03569233505244744, 0.9369497299767974]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9993628263221633, 0.4476172332763264], "y": [0.03569233505244744, -0.8942252380303364]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, 0.6943730118413456], "y": [0.05352428641599974, 0.7196152808833014]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, 0.017849051330050086], "y": [0.05352428641599974, 0.9998406767846604]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, -4.28273448436353e-08], "y": [0.05352428641599974, 1.0]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, -0.6548606738550876], "y": [0.05352428641599974, 0.7557496430711902]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 2}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, -0.850769398938536], "y": [0.05352428641599974, 0.5255391602064499]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, -0.9841111880628256], "y": [0.05352428641599974, -0.17755316090737094]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 4}, "mode": "lines", "type": "scatter", "x": [0.9985665678733333, 0.3494641190467795], "y": [0.05352428641599974, 0.9369497299767974]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9974521398309817, 0.9960198998229769], "y": [0.0713391834005812, 0.08913134866378211]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9942703246864767, 0.9922039508632834], "y": [0.106895119764354, 0.12462483426104831]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9898214340044892, 0.9871235489704753], "y": [0.14231483716319718, 0.15995951073303558]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9871235489704753, 0.9871235489704753], "y": [0.15995951073303558, 0.15995951073303558]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9871235489704753, 0.789717197583763], "y": [0.15995951073303558, 0.6134710315406331]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9871235489704753, 0.7786415221063214], "y": [0.15995951073303558, 0.6274690035394638]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9871235489704753, 0.7196152808575339], "y": [0.15995951073303558, 0.6943729522624683]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.9871235489704753, 0.07133923552887787], "y": [0.15995951073303558, 0.9974521398567492]}, {"hoverinfo": "none", "line": {"color": "#888", "width": 1}, "mode": "lines", "type": "scatter", "x": [0.98411 ...

# %% [markdown]
# c)
# 1. They are really similar, especially for top results
#
# 2. if we want to just have a general picture of the centrality. Degree might work. However, betweeness and page rank both have other prespectives of viewing centrality. betweeness shows how important one node is between groups. page rank explicitly shows authority of this node.
#
# for this hashtag #photography i chose, probably page rank makes more sense.

# %% [markdown]
# # Q5 Cliques analysis

# %% [markdown]
# a) 1. number of maximal cliques

# %%
num_maxCliques = nx.graph_number_of_cliques(pgGraph)
num_maxCliques
# Out:
# 264

# %%
fc = nx.find_cliques(pgGraph)
fc
# Out:
# <generator object find_cliques at 0x7efc04a11048>

# %% [markdown]
# 2. size of the largest maximal clique containing each given node

# %%
cliques_number = nx.node_clique_number(pgGraph)
cliques_number
sorted(cliques_number.items(), key=lambda x: -x[1])[:10]
# Out:
# [('photocentrum', 3),
#  ('', 3),
#  ('havepack', 3),
#  ('joanna_haugen', 3),
#  ('lindseygirl', 3),
#  ('gullivergo', 3),
#  ('catherinegrison', 3),
#  ('2live4him', 3),
#  ('str8photography', 3),
#  ('rweiher', 3)]

# %%
# some other findings
# find cliques
gclique = list(nx.find_cliques(pgGraph))
print (gclique)
# find connected components
comps = nx.connected_components(pgGraph)
#print (len(comps))
#print (comps[0])
#print (comps[1])
print (comps)
# Out:
# [['', 'thagoodson'], ['', 'anthonymartinez'], ['', 'birdfeeders'], ['', 'steffilewis'], ['', 'fpresources', 'photocentrum'], ['', 'fpresources', 'catherinegrison'], ['', 'birdingoz'], ['photocriticnews', 'digitalmon'], ['passepartout', 'lindseygirl'], ['besttravelpics)', 'amyhale'], ['scottehorton', 'monitter'], ['foodimages', 'tweets2go'], ['desizntech', 'r27', 'redmanandy'], ['credd', 'rweiher'], ['heathrowe', 'mitzs'], ['heathrowe', 'rweiher'], ['latimesphotos', 'dsrosenthal'], ['latimesphotos', 'kellyshipp'], ['latimesphotos', 'karensperling'], ['latimesphotos', 'alexanderichter'], ['latimesphotos', 'mysticb'], ['latimesphotos', 'angelsamudre'], ['safesolvent', 'ncbeets'], ['calumetphoto', 'theloftphoto'], ['yancyjones', 'photoframd'], ['2live4him', 'str8photography', 'bpfox4'], ['dani', 'merttol'], ['jiimmy', 'iphonegirl'], ['brazilianart', 'hashphoto'], ['brazilianart', 'getphotograjobs)'], ['0lli', 'photoframd'], ['-reply', 'twitographers'], ['apollophoto', 'smartard'], ['apollophoto', 'rweiher', 'durbindigital'], ['apollophoto', 'twitographers:people,its'], ['apollophoto', 'shontaeb'], ['walker_photo', 'rtphotographer'], ['sandyguerriere', 'splashvafashnwk'], ['beyondmegapixelshttp://tinyurl.com/y4lug8', 'bo_mackison'], ['6alkal6', 'surferess'], ['ymerej', 'murrayed'], ['bucketheadphoto', 'hdrphotography'], ['melaniewci', 'jasondpg'], ['murrayed', 'pwcarey'], ['misterjezmond', 'chriseden'], ['added', 'lrockwellatty'], ['earthxplorer', 'vanphotolens'], ['dianakhalil', 'aj_wood'], ['maciek416', 'redesign'], ['futurowoman', 'polaroidgirl'], ['swichi293', 'frugalnyc'], ['polaroidteam', 'jeanevogel}'], ['polaroidteam', 'amnesiak1978'], ['polaroidteam', 'polaroidgirl'], ['polaroidteam', 'jerseymaids'], ['sonofgroucho', 'hashphotoshopchanging'], ['sonofgroucho', 'robinmwood'], ['sonofgroucho', 'grunberghausvt'], ['sonofgroucho', 'brighteyedphoto'], ['pairadocsdesign', 'aj_wood'], ['photoclog', 'hfood'], ['lucatoledo', 'trendtracker)'], ['joanna_haugen', 'havepack', 'gullivergo'], ['joanna_haugen', 'havepack', 'lindseygirl'], ['peterliuphoto', '1001noisycamera'], ['ruphotography', 'csoltis'], ['tobyct', 'twitographers'], ['tobyct', 'ivanlo_photo'], ['smptoday', 'splashvafashnwk'], ['smptoday', 'hashphoto'], ['smptoday', 'photobloggingdc)'], ['satureyes', 'twitographers'], ['amazingpics', 'wearephotogs)', 'phototube'], ['amazingpics', 'wearephotogs)', 'jeremyteocx'], ['amazingpics', 'wearephotogs)', 'nminers'], ['amazingpics', 'wearephotogs)', 'nynabl'], ['amazingpics', 'wearephotogs)', 'buonaluce'], ['amazingpics', 'wearephotogs)', 'rhysb123'], ['amazingpics', 'wearephotogs)', 'kellyjo9'], ['amazingpics', 'wearephotogs)', 'my_nicki'], ['amazingpics', 'wearephotogs)', 'fpresources'], ['quiteuseful)', 'svenyurgensson'], ['tasarhane', 'rebeccads'], ['areelulibub', 'bor64'], ['numetrick83', 'bar0s'], ['designerm'], ['ilanbr', 'rhysb123'], ['ilanbr', 'my_nicki'], ['bitfiddler', 'hashphoto'], ['lillithleda', 'rtphotographer'], ['catherinegrison', 'hopfoot', 'fpresources'], ['kymri', 'jainlemos'], ['trentonmoore', 'inf3ktion'], ['deirdreryan', 'glorialynnglass'], ['photosphoenix7', 'lorenzemlicka'], ['photosphoenix7', 'oriole2'], ['photosphoenix7', 'lirothen'], ['photosphoenix7', 'isnap'], ['matthewdlyons', 'hrider'], ['chasejarvis', 'cophotographer'], ['sumsion)', 'stran9ee'], ['beyondmegapixel', '1001noisycamera'], ['cavaroc', 'ggal24'], ['swissphotoguru', 'pixum'], ['tweetmeme)', 'jonnydr'], ['tweetmeme)', 'thornesworld'], ['tweetmeme)', 'shellytucker'], ['shawnduffy', 'photobloggingdc'], ['photocentrum', 'andrewbuxton'], ['kenkohutphoto', 'absolutely_abby'], ['makingpixels', 'jaylevan', 'ice66'], ['saarmst1', 'rweiher'], ['lrockwellatty', 'filllight'], ['ice66', 'anthonymartinez'], ['ice66', 'wearephotogs'], ['ice66', 'stran9ee'], ['ice66', 'xnixrt'], ['mycameraandi', 'inf3ktion'], ['declerck', '1001noisycamera'], ['timestravel', 'leonardodm'], ['kyokes', 'bo_mackison'], ['jdesignz)', 'kellyshipp'], ['margaretkinney', 'rickbakas' ...
# <generator object connected_components at 0x7efc059fee60>

# %%
testGraph = nx.pagerank(pgGraph)
print(testGraph[max(testGraph, key=testGraph.get)])
print(max(testGraph.values()))
# Out:
# 0.030435536044451005
# 0.030435536044451005

# %% [markdown]
# b) insights on connectivity

# %% [markdown]
# so through my hashtag, there are a lot of cliques but most of them are really small, which means they are not a large group or several large groups.
# as below:

# %%
# Size of the largest maximal clique containing each given node
pd.DataFrame(list(nx.node_clique_number(pgGraph).items()), 
             columns=['user', 'Maximal clique']).sort_values('Maximal clique',ascending=0)
# Out:
#               user  Maximal clique
# 303    yipeedoodah               3
# 282       rhysb123               3
# 79      redmanandy               3
# 37   joanna_haugen               3
# 38     lindseygirl               3
# ..             ...             ...
# 127   thecruiseguy               2
# 126    say_my_name               2
# 125          njray               2
# 334      designerm               1
# 341    darladeleon               1
#
# [352 rows x 2 columns]

# %%
# Maximal cliques for each node
pd.DataFrame(list(nx.number_of_cliques(pgGraph).items()), 
             columns=['user', 'Maximal clique']).sort_values('Maximal clique',ascending=0)
# Out:
#                 user  Maximal clique
# 104       jacksoncj1              23
# 188        hashphoto              12
# 224    wearephotogs)              10
# 223      amazingpics               9
# 64           rweiher               8
# ..               ...             ...
# 130  chacal_lachaise               1
# 129     sherri_meyer               1
# 128       thagoodson               1
# 127     thecruiseguy               1
# 351     angelsamudre               1
#
# [352 rows x 2 columns]

# %% [markdown]
# according to wiki, **The clique problem arises in the following real-world setting. Consider a social network, where the graph's vertices represent people, and the graph's edges represent mutual acquaintance. Then a clique represents a subset of people who all know each other, and algorithms for finding cliques can be used to discover these groups of mutual friends.**

# %% [markdown]
# therefore, from the analysis, we know the user "jacksoncj1" might be the center of several cliques and we can see other potential friends inside cliques as well.

# %%
pd.options.display.max_colwidth = 1000

# %%
# figure our who th is jacksoncj1
pgTag[pgTag['user'] == 'jacksoncj1']
# Out:
#                        date  ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             clean_tweets
# 979278  2009-06-12 14:55:18  ...  leave alternative proceed wage reduction say sulzberger jimcim original composition jim cim jim cim everything via awesome ad louis vutton use astronauts kamytran awww video cuteee khopjackpaper cool tell celeb we're follow actually celebrity thank twitter lasersmom rt develop women's swimwear next season can't decide gold silver metallic accent pick vote win marykenah real housewife nj irl mmasjer hot free video update daily nice cute girl asian european msdrama rt mspbjnews medtronic boston sci torax med get acid reflux-fighting tech onenewsnowcom prejean homosexual comment cost crown former miss california usa carrie prejean say lose crown hoevestein wageningen pigman daft punk light old and/or stupid day work today rss_tennis mobilisation pour sauver les seins de simona halep savereighter awesome complete laundry giveaway frugalgirls schwagerlicious rt seantcallahan toy soldier simbacatog friday human cool tweetpeeps even tho allergic telerikbuzz rt telerik winforms courseware ...
#
# [1 rows x 5 columns]

# %% [markdown]
# I literally check her tweeter account, from her intro:
#
#
# "I'm all about sewing and crafts when I'm not doing marcom for a Big 12 b-school in TX. Sewing, NPR, PBS, saltwater fishing."

# %% [markdown]
# C.J. Jackson (@jacksoncj1) is a social media influencer. but not a photograher as i thought before
